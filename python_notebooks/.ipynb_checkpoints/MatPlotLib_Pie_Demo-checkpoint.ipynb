# %% [markdown]
# ## Single Dimension Array

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [10, 23, 34, 35, 45, 59]
df = pd.DataFrame(data, columns=['Score'])
df
# Out:
#    Score
# 0     10
# 1     23
# 2     34
# 3     35
# 4     45
# 5     59

# %%
#plt.pie(df)
plt.pie(df, labels=df['Score'])
plt.title("Students Score")
plt.show()
# Out:
# /Users/avkashchauhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
label_name = ['John', 'Tim', 'Kenny', 'AK', 'Helvetica', 'Bryan']

# %%
plt.pie(df, labels=label_name)
plt.title("Students Score")
plt.show()
# Out:
# /Users/avkashchauhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.pie(df, labels=label_name, autopct='%1.1f%%')
plt.title("Students Score")
plt.show()
# Out:
# /Users/avkashchauhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.pie(df, labels=label_name, autopct='%1.2f%%')
plt.title("Students Score")
plt.show()
# Out:
# /Users/avkashchauhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.pie(df, labels=label_name, autopct='%1.3f%%')
plt.title("Students Score")
plt.show()
# Out:
# /Users/avkashchauhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Two Dimension Array

# %%
new_data = [['John', 10], ['Tim', 24], ['AK', 34]]

# %%
new_data
# Out:
# [['John', 10], ['Tim', 24], ['AK', 34]]

# %%
newdf = pd.DataFrame(new_data)

# %%
newdf
# Out:
#       0   1
# 0  John  10
# 1   Tim  24
# 2    AK  34

# %%
newdf = pd.DataFrame(new_data, columns=['Name', 'Score'])

# %%
newdf
# Out:
#    Name  Score
# 0  John     10
# 1   Tim     24
# 2    AK     34

# %%
newdf['Score']
# Out:
# 0    10
# 1    24
# 2    34
# Name: Score, dtype: int64

# %%
newdf['Name']
# Out:
# 0    John
# 1     Tim
# 2      AK
# Name: Name, dtype: object

# %%
plt.pie(newdf['Score'], labels=newdf['Name'], autopct='%1.1f%%')
plt.show()
